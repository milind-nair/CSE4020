# %%
import pandas as pd

# %%
from sklearn.datasets import load_iris 
data = load_iris(as_frame=True)
df = pd.DataFrame(data.data)

# %%
df["target"]=data.target

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
import numpy as np
from sklearn import tree
clf  =  tree.DecisionTreeClassifier(criterion='entropy')
img  =clf.fit(np.array(df["sepal length (cm)"]).reshape(-1,1),df["target"])

# %%
tree.plot_tree(img,max_depth=3)
# Out:
# [Text(0.4305555555555556, 0.9, 'X[0] <= 5.55\nentropy = 1.585\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.16666666666666666, 0.7, 'X[0] <= 5.45\nentropy = 0.813\nsamples = 59\nvalue = [47, 11, 1]'),
#  Text(0.1111111111111111, 0.5, 'X[0] <= 4.85\nentropy = 0.65\nsamples = 52\nvalue = [45, 6, 1]'),
#  Text(0.05555555555555555, 0.3, 'entropy = 0.0\nsamples = 16\nvalue = [16, 0, 0]'),
#  Text(0.16666666666666666, 0.3, 'X[0] <= 4.95\nentropy = 0.826\nsamples = 36\nvalue = [29, 6, 1]'),
#  Text(0.1111111111111111, 0.1, '\n  (...)  \n'),
#  Text(0.2222222222222222, 0.1, '\n  (...)  \n'),
#  Text(0.2222222222222222, 0.5, 'entropy = 0.863\nsamples = 7\nvalue = [2, 5, 0]'),
#  Text(0.6944444444444444, 0.7, 'X[0] <= 6.15\nentropy = 1.167\nsamples = 91\nvalue = [3, 39, 49]'),
#  Text(0.5, 0.5, 'X[0] <= 5.85\nentropy = 1.225\nsamples = 36\nvalue = [3, 23, 10]'),
#  Text(0.3888888888888889, 0.3, 'X[0] <= 5.65\nentropy = 1.322\nsamples = 21\nvalue = [3, 13, 5]'),
# ...

# %%
import graphviz 
dot_data = tree.export_graphviz(img,max_depth=3) 
graph = graphviz.Source(dot_data) 
graph

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
from sklearn import svm
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

data = pd.read_csv('linearsvm.csv')
X = data[['x1', 'x2']].values
y = data['y'].values
model = svm.SVC(kernel='linear')
model.fit(X, y)
# Out:
# SVC(kernel='linear')

# %%
plt.scatter(X[:,0],X[:,1],c=y)
plt.scatter(model.support_vectors_[:,0], model.support_vectors_[:,1], color='red')

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=3)
kmeans.cluster_centers_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1044\3012259555.py in <module>
#       1 kmeans = KMeans(n_clusters=3)
# ----> 2 kmeans.cluster_centers_
#
# AttributeError: 'KMeans' object has no attribute 'cluster_centers_'

# %%
from kmodes.kmodes import KModes

# %%
kmodes  = KModes()

# %%
kmodes.c

# %%
from sklearn import metrics

# %%
metrics.mean_squared_error([100],[10])
# Out:
# 8100.0
